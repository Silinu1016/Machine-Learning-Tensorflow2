# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
tf.random.set_seed(777)

# %%
def min_max_scaler(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)
    return numerator / (denominator + 1e-7)

# %%
xy=pd.read_csv('winequality-red.csv')
xy.drop(xy.columns[[2,4,5,6,7,8,9]], axis='columns')
xy=xy.values
xy[:,:-1]=min_max_scaler(xy[:,:-1])
np.random.shuffle(xy)
test_line=int(len(xy)*0.7)
x_data=xy[:test_line,:-1]
y_data=xy[:test_line,[-1]] 
x_test=xy[test_line:,:-1]
y_test=xy[test_line:,[-1]]

# %%
tf.model = tf.keras.Sequential() 
tf.model.add(tf.keras.layers.Dense(input_dim=x_data.shape[1], units=1,activation='linear', use_bias=True))  # use_bias is True, by default 
# use loss == categorical_crossentropy 
tf.model.compile(loss='mse', optimizer=tf.keras.optimizers.SGD(lr=0.1)) 
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 12
# ...
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = tf.model.fit(x_data, y_data, epochs=500) 
prediction_test= tf.model.predict(x_test)
cost_val=tf.model.evaluate(x_data,y_data)
# Out:
# Train on 1119 samples
# Epoch 1/500
# 1119/1119 [==============================] - 0s 149us/sample - loss: 2.0755
# Epoch 2/500
# 1119/1119 [==============================] - 0s 18us/sample - loss: 0.6234
# Epoch 3/500
# 1119/1119 [==============================] - 0s 19us/sample - loss: 0.5681
# Epoch 4/500
# 1119/1119 [==============================] - 0s 19us/sample - loss: 0.5327
# Epoch 5/500
# 1119/1119 [==============================] - 0s 19us/sample - loss: 0.5108
# Epoch 6/500
# 1119/1119 [==============================] - 0s 19us/sample - loss: 0.4969
# Epoch 7/500
# 1119/1119 [==============================] - 0s 19us/sample - loss: 0.4787
# Epoch 8/500
# 1119/1119 [==============================] - 0s 18us/sample - loss: 0.4742
# Epoch 9/500
# 1119/1119 [==============================] - 0s 19us/sample - loss: 0.4668
# Epoch 10/500
# 1119/1119 [==============================] - 0s 18us/sample - loss: 0.4631
# Epoch 11/500
# ...

# %%
print('Prediction test : ',prediction_test)
print('Cost value : ', cost_val)
# Out:
# Prediction test :  [[4.866477 ]
#  [5.0604177]
#  [6.1996155]
#  [5.9049973]
#  [5.3591857]
#  [5.6055226]
#  [5.369898 ]
#  [5.732824 ]
#  [6.5253496]
#  [5.2975855]
#  [5.9062247]
#  [6.470356 ]
#  [6.017212 ]
#  [5.189818 ]
#  [5.0580106]
#  [5.9313107]
#  [5.334485 ]
#  [6.2448573]
#  [5.6167955]
#  [5.365179 ]
#  [5.457455 ]
#  [5.917673 ]
#  [6.2654014]
#  [5.21711  ]
#  [6.175092 ]
#  [5.712295 ]
#  [5.8479676]
#  [5.205289 ]
#  [6.7373686]
#  [6.37875  ]
#  [6.006631 ]
#  [5.4702897]
#  [5.256968 ]
#  [6.073141 ]
#  [6.155542 ]
#  [6.19554  ]
#  [4.9772296]
#  [5.6582346]
#  [5.554879 ]
#  [4.7412353]
#  [5.490645 ]
#  [5.1342072]
#  [5.118549 ]
#  [5.200756 ]
#  [5.299097 ]
#  [5.283178 ]
#  [5.7857275]
#  [5.549792 ]
#  [5.9189386]
#  [6.1258845]
#  [5.017836 ]
#  [5.343005 ]
#  [5.3349795]
#  [5.8000383]
#  [5.635886 ]
#  [5.9081526]
#  [6.472129 ]
#  [5.4844584]
#  [5.3186374]
#  [6.3389473]
#  [5.7654305]
#  [5.7055707]
#  [6.174004 ]
#  [6.044347 ]
#  [5.291404 ]
# ...

# %%
plt.plot(history.history['loss'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
